# %% [markdown]
# # Eaternity API
#
# This is the Eaternity API that can return the carbon impact of the food product/ ingrediant

# %%
import requests
import json
import pandas as pd
import math
import re
from requests.auth import HTTPBasicAuth

YOUR_KEY = "SR012UWDjBT7fgivtbNZSp1IJylocm5a"
AUTH = HTTPBasicAuth(YOUR_KEY, "")
BASE_URL = "https://co2.eaternity.ch"

if YOUR_KEY == "CHANGEME":
    raise RuntimeError("Please change your api key!!")

def create_kitchen(name, kitchen_id, location):
    url = f"{BASE_URL}/api/kitchens/{kitchen_id}"

    body = {
        "kitchen": {
            "name": name,
            "location": location
        }
    }

    response = requests.put(url, json=body, auth=AUTH)
    if response.status_code not in [200, 201, 202]:
        print(f"ERROR: Failed PUTting kitchen {kitchen_id} with status {response.status_code}: '{response.text}'")
    else:
        print(f"SUCCESS: PUT kitchen {kitchen_id}")
        return response.json()

    
def put_recipe(recipe_id, recipe_name, kitchen_id, ingredients, bad_ingr):
    url = f"{BASE_URL}/api/kitchens/{kitchen_id}/recipes/{recipe_id}"

    ingredient_list = []
    for ingredient in ingredients.keys():
        if ingredient not in bad_ingr:
            print(ingredient)
            ingred_dict = {
                "id": ingredient,
                "names": [{"language": "en", "value": ingredient}],
                "amount": ingredients[ingredient],
                "unit": "gram"
            }
            ingredient_list.append(ingred_dict)
        
    body = {
        "recipe": {
            "titles": [
                {
                    "language": "en",
                    "value": recipe_name
                }
            ],
            "date": "2020-09-19",
            "location": "Schweiz",
            "servings": 1,
            "ingredients": ingredient_list
        }
    }

    response = requests.put(url, json=body, auth=AUTH)
    
    if response.status_code in [601, 602]:
        print(response.text)
        bad_ingredient = re.findall(r"FoodService(.*)\\", response.text)[0]
        bad_ingr.append(bad_ingredient.lower().strip())
        print(bad_ingr)
        put_recipe(recipe_id, recipe_name, kitchen_id, ingredients, bad_ingr)
    
    elif response.status_code not in [200, 201, 202]:
        print(f"ERROR: Failed PUTting recipe {recipe_id} with status {response.status_code}: '{response.text}'")
    else:
        print(f"SUCCESS: PUT recipe {recipe_id}")
        print(response.json())
        print(bad_ingr)
        return response.json()


if __name__ == '__main__':
    kitchen_id = "our_name_id"
    create_kitchen("My First Kitchen", kitchen_id, "Switzerland")
    
    xls = pd.ExcelFile('SwissRe Sourcing Data.xlsx')
    recipes = pd.read_excel(xls, 'Menus', header=1)
    
    vegan_dict = {}
    vegetarian_dict = {}
    meat_dict = {}
    
    for index, row in recipes.iterrows():
        recipe = {}
        rowiter = 0
        for rowiter in range(8, 34, 2):
            if not pd.isnull(row[rowiter]):
                recipe[row[rowiter+1].lower().strip()] = row[rowiter]
        
        if row[5] == 'x': #Checking if vegan
            vegan_dict[row['Name']] = recipe
        elif row[6] == 'x': #Checking if vegan
            vegetarian_dict[row['Name']] = recipe
        else:
            meat_dict[row['Name']] = recipe
    
    #Create a list of ingredients that return errors from the eaternity
    #write carbon dictionary to file
    bad_ingr = []
    vegan_carbon_list = []
    for index, key in enumerate(vegan_dict):
        recipe_return = put_recipe(index, key, kitchen_id, vegan_dict[key], bad_ingr)
        print(recipe_return)
        vegan_carbon_list.append(recipe_return)
    
    with open('vegan.json', 'w') as fp:
        json.dump(vegan_carbon_list, fp)
    
    vegetarian_carbon_list = []
    for index, key in enumerate(vegetarian_dict):
        recipe_return = put_recipe(index, key, kitchen_id, vegetarian_dict[key], bad_ingr)
        print(recipe_return)
        vegetarian_carbon_list.append(recipe_return)
    
    with open('vegetarian.json', 'w') as fp:
        json.dump(vegetarian_carbon_list, fp)
    
    meat_carbon_list = []
    for index, key in enumerate(meat_dict):
        recipe_return = put_recipe(index, key, kitchen_id, meat_dict[key], bad_ingr)
        print(recipe_return)
        meat_carbon_list.append(recipe_return)
    
    with open('meat.json', 'w') as fp:
        json.dump(vegan_carbon_list, fp)
# Out:
# SUCCESS: PUT kitchen our_name_id
# spaghetti
# canola oil
# onions
# tomatoes
# "Linking Product with id \"FoodServiceCanola oil\" is not yet matched. Retry next day."
# ['canola oil']
# spaghetti
# onions
# tomatoes
# SUCCESS: PUT recipe 0
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '0', 'recipe': {'id': '0', 'kitchen-id': 'our_name_id', 'co2-value': 423, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Pasta'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.8453666242424243}}
# ['canola oil']
# None
# bread
# zucchini
# aubergine
# red bell pepper
# leek
# "Linking Product with id \"FoodServiceRed bell pepper\" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper']
# bread
# zucchini
# aubergine
# leek
# SUCCESS: PUT recipe 1
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '1', 'recipe': {'id': '1', 'kitchen-id': 'our_name_id', 'co2-value': 550, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Vegi Sandwich'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.9969582181818183}}
# ['canola oil', 'red bell pepper']
# None
# tomatoes
# broth
# parsely
# sugar
# onion
# "Linking Product with id \"FoodServiceParsely \" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely']
# tomatoes
# broth
# sugar
# onion
# SUCCESS: PUT recipe 2
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '2', 'recipe': {'id': '2', 'kitchen-id': 'our_name_id', 'co2-value': 1084, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Tomato soup'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.1623272303030303}}
# ['canola oil', 'red bell pepper', 'parsely']
# None
# red lentils
# tumeric
# garlic
# ginger
# broth
# coconut milk
# leek
# spinach
# "Linking Product with id \"FoodServicetumeric\" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric']
# red lentils
# garlic
# ginger
# broth
# coconut milk
# leek
# spinach
# SUCCESS: PUT recipe 3
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '3', 'recipe': {'id': '3', 'kitchen-id': 'our_name_id', 'co2-value': 517, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Lentil and coconut soup'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 1.0077029190909086}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric']
# None
# peppers
# tofu
# dates
# carrots
# harissa
# olive oil
# "Linking Product with id \"FoodServicepeppers\" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers']
# tofu
# dates
# carrots
# harissa
# olive oil
# SUCCESS: PUT recipe 4
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '4', 'recipe': {'id': '4', 'kitchen-id': 'our_name_id', 'co2-value': 608, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Peppers stuffed with tofu'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.4364229750552251}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers']
# None
# tofu
# potato
# artichokes
# thyme
# rosmary
# mango
# "Linking Product with id \"FoodServicerosmary \" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary']
# tofu
# potato
# artichokes
# thyme
# mango
# SUCCESS: PUT recipe 5
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '5', 'recipe': {'id': '5', 'kitchen-id': 'our_name_id', 'co2-value': 620, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Tofu escalope'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.8637156442424242}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary']
# None
# carrot
# coconut milk
# onion
# garlic
# parsley
# lemon
# SUCCESS: PUT recipe 6
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '6', 'recipe': {'id': '6', 'kitchen-id': 'our_name_id', 'co2-value': 657, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Carrot and coconut soup'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.7494216381818182}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary']
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '6', 'recipe': {'id': '6', 'kitchen-id': 'our_name_id', 'co2-value': 657, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Carrot and coconut soup'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.7494216381818182}}
# mushrooms
# broth
# carrots
# parsnips
# red bell peppers
# "Linking Product with id \"FoodServicered bell peppers\" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers']
# mushrooms
# broth
# carrots
# parsnips
# SUCCESS: PUT recipe 7
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '7', 'recipe': {'id': '7', 'kitchen-id': 'our_name_id', 'co2-value': 1679, 'eaternity-award': False, 'rating': 'C', 'titles': [{'language': 'en', 'value': 'Mushroom broth with vegeatables'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.21531205393939395}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers']
# None
# beetroot
# miso
# glass noodles
# ginger
# soy sauce
# SUCCESS: PUT recipe 8
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '8', 'recipe': {'id': '8', 'kitchen-id': 'our_name_id', 'co2-value': 405, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Crispy Organic Beetroot and Miso'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.7228062071212109}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers']
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '8', 'recipe': {'id': '8', 'kitchen-id': 'our_name_id', 'co2-value': 405, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Crispy Organic Beetroot and Miso'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.7228062071212109}}
# chickpeas
# broth
# coconut milk
# pumpkin
# cauliflower
# spinach
# poppadoms
# "Linking Product with id \"FoodServicePoppadoms\" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers', 'poppadoms']
# chickpeas
# broth
# coconut milk
# pumpkin
# cauliflower
# spinach
# SUCCESS: PUT recipe 9
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '9', 'recipe': {'id': '9', 'kitchen-id': 'our_name_id', 'co2-value': 595, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Chickpea curry with vegetables'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.889714256969697}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers', 'poppadoms']
# None
# tofu
# miso
# ginger
# rice
# zucchini
# soy sauce
# SUCCESS: PUT recipe 10
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '10', 'recipe': {'id': '10', 'kitchen-id': 'our_name_id', 'co2-value': 751, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Tofu with vegetables'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 1.0916083337878788}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers', 'poppadoms']
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '10', 'recipe': {'id': '10', 'kitchen-id': 'our_name_id', 'co2-value': 751, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Tofu with vegetables'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 1.0916083337878788}}
# kidney beans
# tomato sugo
# corn
# rice
# coriander
# SUCCESS: PUT recipe 11
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '11', 'recipe': {'id': '11', 'kitchen-id': 'our_name_id', 'co2-value': 727, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Chili con verdure'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.8604540854545455}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers', 'poppadoms']
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '11', 'recipe': {'id': '11', 'kitchen-id': 'our_name_id', 'co2-value': 727, 'eaternity-award': False, 'rating': 'B', 'titles': [{'language': 'en', 'value': 'Chili con verdure'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 0.8604540854545455}}
# quinoa
# spring onions
# leek
# tomato
# balsamico
# mustard
# SUCCESS: PUT recipe 12
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '12', 'recipe': {'id': '12', 'kitchen-id': 'our_name_id', 'co2-value': 334, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Quinoa salad'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 1.2401906751515153}}
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers', 'poppadoms']
# {'statuscode': 200, 'message': '', 'request-id': 0, 'recipe-id': '12', 'recipe': {'id': '12', 'kitchen-id': 'our_name_id', 'co2-value': 334, 'eaternity-award': True, 'rating': 'A', 'titles': [{'language': 'en', 'value': 'Quinoa salad'}], 'date': '2020-09-19', 'location': 'Schweiz', 'servings': 1, 'recipe-portions': 1, 'ingredients': [], 'food-unit': 1.2401906751515153}}
# carrot
# onion
# leek
# mushroom
# parsnip
# chili
# broth
# parsley
# "Linking Product with id \"FoodServicemushroom\" is not yet matched. Retry next day."
# ['canola oil', 'red bell pepper', 'parsely', 'tumeric', 'peppers', 'rosmary', 'red bell peppers', 'poppadoms', 'mushroom']
# carrot
# onion
# leek
# parsnip
# chili
# broth
# parsley

# %%
recipes
# Out:
#     Menu + Option Unnamed: 1                                  Name  \
# 0          Menu 1   Option 1                Chantarelle Sour Cream
# 1             NaN   Option 2                            Roast Beef
# 2             NaN   Option 3                                 Pasta
# 3             NaN   Option 4           Fish stikcs with vegetables
# 4             NaN   Option 5                           Ham Sandich
# ..            ...        ...                                   ...
# 146           NaN   Option 2  Veal with chantarelles and fetuccine
# 147           NaN   Option 3          Fillet of Sea-bass with rice
# 148           NaN   Option 4                  Cevapcici with ajvar
# 149           NaN   Option 5                           Fresh salad
# 150           NaN   Option 6                                   NaN
#
#     Lactose free? Gluten Free? Vegan? Vegetarian? Grab and Go?  Amount g  \
# 0             NaN            x    NaN           x            x     150.0
# 1             NaN            x    NaN         NaN          NaN     210.0
# 2             NaN          NaN      x           x          NaN     120.0
# 3             NaN            x    NaN         NaN            x     200.0
# 4             NaN          NaN    NaN         NaN            x     200.0
# ..            ...          ...    ...         ...          ...       ...
# 146           NaN          NaN    NaN         NaN          NaN     180.0
# 147           NaN          NaN    NaN         NaN          NaN     190.0
# 148           NaN          NaN    NaN         NaN          NaN     180.0
# 149           NaN          NaN    NaN         NaN          NaN      80.0
# 150           NaN          NaN    NaN         NaN          NaN       NaN
#
#                  Product 1  ...  Amount g.8        Product 9  Amount g.9  \
# 0    Chantarelle mushrooms  ...         NaN              NaN         NaN
# 1                     Beef  ...        40.0  Parmesan cheese        10.0
# 2                Spaghetti  ...         NaN              NaN         NaN
# 3              Fish sticks  ...        10.0           garlic        20.0
# 4                    bread  ...         NaN              NaN         NaN
# ..                     ...  ...         ...              ...         ...
# 146                   veal  ...         NaN              NaN         NaN
# 147          sea bass fish  ...         NaN              NaN         NaN
# 148                   beef  ...         NaN              NaN         NaN
# 149            red cabbage  ...         NaN              NaN         NaN
# 150                    NaN  ...         NaN              NaN         NaN
#
#      Product 10  Amount g.10 Product 11  Amount g.11 Product 12  Amount g.12  \
# 0           NaN          NaN        NaN          NaN        NaN          NaN
# 1         cream         50.0   Tomatoes        100.0   Zucchini         50.0
# 2           NaN          NaN        NaN          NaN        NaN          NaN
# 3    canola oil         15.0  soy sauce         10.0     sambal          NaN
# 4           NaN          NaN        NaN          NaN        NaN          NaN
# ..          ...          ...        ...          ...        ...          ...
# 146         NaN          NaN        NaN          NaN        NaN          NaN
# 147         NaN          NaN        NaN          NaN        NaN          NaN
# 148         NaN          NaN        NaN          NaN        NaN          NaN
# 149         NaN          NaN        NaN          NaN        NaN          NaN
# 150         NaN          NaN        NaN          NaN        NaN          NaN
#
#           Product 13
# 0                NaN
# 1    Red bell pepper
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 146              NaN
# 147              NaN
# 148              NaN
# 149              NaN
# 150              NaN
#
# [151 rows x 34 columns]

# %%
vegetarian = recipes.loc[recipes['Vegetarian?'] == 'x']

# %%
vegetarian.head()
# Out:
#    Menu + Option Unnamed: 1                    Name Lactose free?  \
# 0         Menu 1   Option 1  Chantarelle Sour Cream           NaN
# 2            NaN   Option 3                   Pasta           NaN
# 5            NaN   Option 6           Vegi Sandwich           NaN
# 7         Menu 2   Option 1             Tomato soup           NaN
# 10           NaN   Option 4               Shakshuka             x
#
#    Gluten Free? Vegan? Vegetarian? Grab and Go?  Amount g  \
# 0             x    NaN           x            x     150.0
# 2           NaN      x           x          NaN     120.0
# 5           NaN      x           x            x     200.0
# 7             x      x           x            x     150.0
# 10            x    NaN           x          NaN     200.0
#
#                 Product 1  ...  Amount g.8 Product 9  Amount g.9 Product 10  \
# 0   Chantarelle mushrooms  ...         NaN       NaN         NaN        NaN
# 2               Spaghetti  ...         NaN       NaN         NaN        NaN
# 5                   bread  ...         NaN       NaN         NaN        NaN
# 7                tomatoes  ...         NaN       NaN         NaN        NaN
# 10               tomatoes  ...         NaN       NaN         NaN        NaN
#
#     Amount g.10 Product 11  Amount g.11 Product 12  Amount g.12 Product 13
# 0           NaN        NaN          NaN        NaN          NaN        NaN
# 2           NaN        NaN          NaN        NaN          NaN        NaN
# 5           NaN        NaN          NaN        NaN          NaN        NaN
# 7           NaN        NaN          NaN        NaN          NaN        NaN
# 10          NaN        NaN          NaN        NaN          NaN        NaN
#
# [5 rows x 34 columns]

# %%
vegan = recipes.loc[recipes['Vegan?'] == 'x']

# %%
vegan.head()
# Out:
#    Menu + Option Unnamed: 1                       Name Lactose free?  \
# 2            NaN   Option 3                      Pasta           NaN
# 5            NaN   Option 6              Vegi Sandwich           NaN
# 7         Menu 2   Option 1                Tomato soup           NaN
# 19        Menu 4   Option 1    Lentil and coconut soup             x
# 22           NaN   Option 4  Peppers stuffed with tofu             x
#
#    Gluten Free? Vegan? Vegetarian? Grab and Go?  Amount g    Product 1  ...  \
# 2           NaN      x           x          NaN     120.0    Spaghetti  ...
# 5           NaN      x           x            x     200.0        bread  ...
# 7             x      x           x            x     150.0     tomatoes  ...
# 19            x      x           x            x      40.0  red lentils  ...
# 22            x      x           x            x     150.0      Peppers  ...
#
#     Amount g.8 Product 9  Amount g.9 Product 10  Amount g.10 Product 11  \
# 2          NaN       NaN         NaN        NaN          NaN        NaN
# 5          NaN       NaN         NaN        NaN          NaN        NaN
# 7          NaN       NaN         NaN        NaN          NaN        NaN
# 19         NaN       NaN         NaN        NaN          NaN        NaN
# 22         NaN       NaN         NaN        NaN          NaN        NaN
#
#     Amount g.11 Product 12  Amount g.12 Product 13
# 2           NaN        NaN          NaN        NaN
# 5           NaN        NaN          NaN        NaN
# 7           NaN        NaN          NaN        NaN
# 19          NaN        NaN          NaN        NaN
# 22          NaN        NaN          NaN        NaN
#
# [5 rows x 34 columns]

# %%
meat = recipes.loc[recipes['Vegetarian?'] != 'x']

# %%
meat.head()
# Out:
#   Menu + Option Unnamed: 1                         Name Lactose free?  \
# 1           NaN   Option 2                   Roast Beef           NaN
# 3           NaN   Option 4  Fish stikcs with vegetables           NaN
# 4           NaN   Option 5                  Ham Sandich           NaN
# 6           NaN   Option 7       Chicken Satay Sandwich           NaN
# 8           NaN   Option 2           Sauteed Pork steam           NaN
#
#   Gluten Free? Vegan? Vegetarian? Grab and Go?  Amount g    Product 1  ...  \
# 1            x    NaN         NaN          NaN     210.0         Beef  ...
# 3            x    NaN         NaN            x     200.0  Fish sticks  ...
# 4          NaN    NaN         NaN            x     200.0        bread  ...
# 6          NaN    NaN         NaN            x     200.0        bread  ...
# 8          NaN    NaN         NaN          NaN     210.0         Pork  ...
#
#    Amount g.8        Product 9  Amount g.9  Product 10  Amount g.10  \
# 1        40.0  Parmesan cheese        10.0       cream         50.0
# 3        10.0           garlic        20.0  canola oil         15.0
# 4         NaN              NaN         NaN         NaN          NaN
# 6         NaN              NaN         NaN         NaN          NaN
# 8         NaN              NaN         NaN         NaN          NaN
#
#   Product 11  Amount g.11 Product 12  Amount g.12       Product 13
# 1   Tomatoes        100.0   Zucchini         50.0  Red bell pepper
# 3  soy sauce         10.0     sambal          NaN              NaN
# 4        NaN          NaN        NaN          NaN              NaN
# 6        NaN          NaN        NaN          NaN              NaN
# 8        NaN          NaN        NaN          NaN              NaN
#
# [5 rows x 34 columns]

# %%
recipe_dict = {}
for index, row in recipes.iterrows():
    recipe = {}
    rowiter = 0
    for rowiter in range(8, 34, 2):
        if row[rowiter] != None:
            recipe[row[rowiter+1]] = row[rowiter]
    recipe_dict[row['Name']] = recipe
